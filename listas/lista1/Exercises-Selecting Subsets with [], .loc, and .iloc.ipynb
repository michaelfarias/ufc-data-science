# %%
import pandas as pd

# %%
df = pd.read_csv('food_inspections_map.csv')
df.head()
# Out:
# C:\Users\Michael\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                     dba_name                      aka_name  license  \
# 0               DANY'S TACOS                  DANY'S TACOS  2511723
# 1      BILLY FOOD MARKET INC             BILLY FOOD MARKET  2517614
# 2  TAQUERIA HACIENDA TAPATIA     TAQUERIA HACIENDA TAPATIA  2517707
# 3     WILD GOOSE BAR & GRILL        WILD GOOSE BAR & GRILL    12475
# 4         PUBLICAN TAVERN K1  PUBLICAN TAVERN K1 (T3 MAIN)    34173
#
#   facility_type           risk              address     city state    zip  \
# 0    Restaurant  Risk 1 (High)  2857 S ST LOUIS AVE  CHICAGO    IL  60623
# 1           NaN   Risk 3 (Low)  3906 W ROOSEVELT RD  CHICAGO    IL  60624
# 2    Restaurant  Risk 1 (High)       4125 W 26TH ST  CHICAGO    IL  60623
# ...

# %%
#Exercise 1
df = df.set_index('dba_name')
df.head()
# Out:
#                                                aka_name  license  \
# dba_name
# DANY'S TACOS                               DANY'S TACOS  2511723
# BILLY FOOD MARKET INC                 BILLY FOOD MARKET  2517614
# TAQUERIA HACIENDA TAPATIA     TAQUERIA HACIENDA TAPATIA  2517707
# WILD GOOSE BAR & GRILL           WILD GOOSE BAR & GRILL    12475
# PUBLICAN TAVERN K1         PUBLICAN TAVERN K1 (T3 MAIN)    34173
#
#                           facility_type           risk              address  \
# dba_name
# DANY'S TACOS                 Restaurant  Risk 1 (High)  2857 S ST LOUIS AVE
# BILLY FOOD MARKET INC               NaN   Risk 3 (Low)  3906 W ROOSEVELT RD
# TAQUERIA HACIENDA TAPATIA    Restaurant  Risk 1 (High)       4125 W 26TH ST
# WILD GOOSE BAR & GRILL       Restaurant  Risk 1 (High)   4265 N LINCOLN AVE
# PUBLICAN TAVERN K1           Restaurant  Risk 1 (High)    11601 W TOUHY AVE
#
#                               city state    zip inspection_date  \
# dba_name
# ...

# %%
#Exercise 2
df['risk'].head()
df.risk.head()
# Out:
# dba_name
# DANY'S TACOS                 Risk 1 (High)
# BILLY FOOD MARKET INC         Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA    Risk 1 (High)
# WILD GOOSE BAR & GRILL       Risk 1 (High)
# PUBLICAN TAVERN K1           Risk 1 (High)
# Name: risk, dtype: object

# %%
#Exercise 3
df[['risk', 'results']]
# Out:
#                                                           risk  \
# dba_name
# DANY'S TACOS                                     Risk 1 (High)
# BILLY FOOD MARKET INC                             Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA                        Risk 1 (High)
# WILD GOOSE BAR & GRILL                           Risk 1 (High)
# PUBLICAN TAVERN K1                               Risk 1 (High)
# LABRIOLA BAKERY AND CAFE                       Risk 2 (Medium)
# PARK  PLAZA RETIREMENT CENTER                    Risk 1 (High)
# SULLIVAN'S STEAKHOUSE                            Risk 1 (High)
# THRESHOLD SCHOOL                                 Risk 1 (High)
# EDIBLE ARRANGEMENTS OF CHICAGO-HYDE PARK         Risk 1 (High)
# ONE NORTH                                        Risk 1 (High)
# FRONT YARD JERK GRILLE                           Risk 1 (High)
# VILLA PALERMO INC                                Risk 1 (High)
# ST. BENEDICT ELEMENTARY SCHOOL                   Risk 1 (High)
# ...

# %%
#Exercise 4
df[['facility_type']] #DataFrame
# Out:
#                                                                  facility_type
# dba_name
# DANY'S TACOS                                                        Restaurant
# BILLY FOOD MARKET INC                                                      NaN
# TAQUERIA HACIENDA TAPATIA                                           Restaurant
# WILD GOOSE BAR & GRILL                                              Restaurant
# PUBLICAN TAVERN K1                                                  Restaurant
# LABRIOLA BAKERY AND CAFE                                                Bakery
# PARK  PLAZA RETIREMENT CENTER                                       Restaurant
# SULLIVAN'S STEAKHOUSE                                               Restaurant
# THRESHOLD SCHOOL                                                        School
# EDIBLE ARRANGEMENTS OF CHICAGO-HYDE PARK                            Restaurant
# ONE NORTH                                                           Restaurant
# ...

# %%
#Exercise 5
df.loc['WILD GOOSE BAR & GRILL'] #selecting rows
# Out:
#                                       aka_name license facility_type  \
# dba_name
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL   12475    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL   12475    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL   12475    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL   12475    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL   12475    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL   12475    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL   12475    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL   12475    Restaurant
#
#                                  risk             address     city state  \
# dba_name
# WILD GOOSE BAR & GRILL  Risk 1 (High)  4265 N LINCOLN AVE  CHICAGO    IL
# WILD GOOSE BAR & GRILL  Risk 1 (High)  4265 N LINCOLN AVE  CHICAGO    IL
# WILD GOOSE BAR & GRILL  Risk 1 (High)  4265 N LINCOLN AVE  CHICAGO    IL
# ...

# %%
#Exercise 6
df.loc[['WILD GOOSE BAR & GRILL', 'TAQUERIA HACIENDA TAPATIA'], ['risk', 'results']]
# Out:
#                                     risk results
# dba_name
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Fail
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Fail
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)    Pass
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)    Fail

# %%
#Exercise 7
df.loc['SCRUB A DUB', 'risk']
# Out:
# 'Risk 2 (Medium)'

# %%
df.loc['THRESHOLD SCHOOL':'SCRUB A DUB':3000,'inspection_type':]
#df.loc['THRESHOLD SCHOOL':'SCRUB A DUB':3000, 'risk':]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-5afb15e3620c> in <module>()
# ----> 1 df.loc['THRESHOLD SCHOOL':'SCRUB A DUB':3000,'inspection_type':]
#       2 #df.loc['THRESHOLD SCHOOL':'SCRUB A DUB':3000, 'risk':]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     854                 continue
#     855
# --> 856             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     857
#     858         return retval
#
# ...

# %%
#Exercise 9
df.iloc[500:510]
# Out:
#                                                   aka_name  license  \
# dba_name
# PENINSULA CHICAGO,LLC                         MAIN KITCHEN  1091966
# VENEZUELAN BOWL GRILL LLC            VENEZUELAN BOWL GRILL  2424110
# JULIUS MEINL                                  JULIUS MEINL  2141409
# MEZQUITE EXPRESS # 2                  MEZQUITE EXPRESS # 2  2517585
# PORTILLO'S HOT DOGS                    PORTILLO'S HOT DOGS    39472
# SEE THRU CHINESE RESTAURANT    SEE THRU CHINESE RESTAURANT  1942299
# DENOVA FRESH MARKET                   MARTHA'S FOOD MARKET  2517805
# SOUTH LOOP MONTESSORI SCHOOL  SOUTH LOOP MONTESSORI SCHOOL  2517217
# LORETTO HOSPITAL                          LORETTO HOSPITAL  2204616
# MONTROSE DELI & FRUIT MARKET  MONTROSE DELI & FRUIT MARKET    20886
#
#                                       facility_type           risk  \
# dba_name
# PENINSULA CHICAGO,LLC                    Restaurant  Risk 1 (High)
# ...

# %%
#Exercise 10
df.iloc[[100,1000,10000],[5,3,1]]
# Out:
#                    city           risk  license
# dba_name
# A-Z SALES INC.  CHICAGO  Risk 1 (High)  1490343
# ANONG INC.      CHICAGO  Risk 1 (High)  1942424
# ELVIA GAMA      CHICAGO  Risk 1 (High)  2423902

# %%
#exercise 11
risk = df.loc[:, 'risk']
risk.head()
# Out:
# dba_name
# DANY'S TACOS                 Risk 1 (High)
# BILLY FOOD MARKET INC         Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA    Risk 1 (High)
# WILD GOOSE BAR & GRILL       Risk 1 (High)
# PUBLICAN TAVERN K1           Risk 1 (High)
# Name: risk, dtype: object

# %%
#exercise 12
risk.loc[['ARBYS', 'POPEYES FAMOUS FRIED CHIKEN']]
# Out:
# dba_name
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ARBYS                          Risk 1 (High)
# ...
